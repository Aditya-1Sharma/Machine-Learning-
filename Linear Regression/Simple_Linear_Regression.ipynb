# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("car_data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
# 5      Dealer       Manual      0
# 6      Dealer       Manual      0
# 7      Dealer       Manual      0
# 8      Dealer       Manual      0
# 9      Dealer       Manual      0

# %%
plt.scatter(df['Present_Price'], df['Selling_Price'])
plt.xlabel("Present Price")
plt.ylabel("Selling Price")
plt.title("Present Price vs Selling Price")
plt.show()

# %%
X = df.iloc[:, 3:4]  
y = df.iloc[:, 2]

# %%
X.head()
# Out:
#    Present_Price
# 0           5.59
# 1           9.54
# 2           9.85
# 3           4.15
# 4           6.87

# %%
X.shape
# Out:
# (301, 1)

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([11.17041946,  1.16826435,  4.19276437,  3.79520623,  8.28557448,
#         4.009276  ,  4.6922605 ,  5.13569073,  0.98681473,  4.6769698 ,
#         5.84415973,  4.28960546,  1.01229923,  7.67904346,  3.00518684,
#         1.2314659 ,  1.1906907 ,  1.01229923,  7.67904346,  3.70346204,
#         1.97051629,  7.88291944,  1.02249303,  7.67904346,  1.1957876 ,
#         6.0378419 ,  1.15501241,  1.12952791,  3.00518684,  2.86247366,
#         1.00720233,  3.00518684,  4.62090391,  7.67904346,  1.14838644,
#         5.53834577,  5.53834577,  4.38134964,  5.84415973,  5.53834577,
#        16.34886911,  1.1906907 ,  1.02249303,  1.28243489,  5.29879151,
#         5.53834577,  1.11423721,  5.53834577, 12.54658226,  2.77582637,
#         6.0378419 ,  1.2314659 , 10.23259   ,  1.16520621,  1.2314659 ,
#         1.14838644,  1.07346202, 12.35799699,  1.2314659 ,  1.04288063,
#         8.94817138])

# %%
single_pred = lr.predict(X_test.iloc[1].values.reshape(1,1))
# Out:
# C:\Users\sharm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
single_pred[0]
# Out:
# np.float64(1.1682643471209722)

# %%
plt.scatter(df['Present_Price'], df['Selling_Price'], label='Actual Data')
plt.plot(X_train, lr.predict(X_train), color="red", label='Regression Line')
plt.xlabel("Present Price")
plt.ylabel("Selling Price")
plt.title("Linear Regression: Price Prediction")
plt.legend()
plt.show()

# %%
m = lr.coef_[0]
b = lr.intercept_

# %%
m
# Out:
# np.float64(0.5096899262447698)

# %%
b
# Out:
# np.float64(0.7472604680427923)

# %%
manual_y = m * 5.59 + b

# %%
manual_y
# Out:
# np.float64(3.5964271557510554)

# %%
y = m*5.59 + b

# %%
print(y)
# Out:
# 3.5964271557510554
